# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.load("./KNN/Data/Classification/X_data.npy")
y = np.load("./KNN/Data/Classification/Y_data.npy")

# %%
plt.scatter(X[:,0],X[:,1], c=y)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNNC = KNeighborsClassifier(n_neighbors=5)
KNNC.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
KNNC.predict([X[10]])
# Out:
# array([1])

# %%
y[10]
# Out:
# 1

# %%
KNNC.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
KNNC?
